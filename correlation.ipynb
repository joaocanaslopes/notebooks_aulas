# %% [markdown]
# <a href="https://colab.research.google.com/github/joaocanaslopes/notebooks_aulas/blob/main/correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analysis and Visualization of Complex Agro-Environmental Data
# ---
# ## Correlation

# %% [markdown]
# ### 1. The bivariate normal distribution
#
# Sometimes we can get information about how two variables (or more) relate simply by plot them
# together. The following example shows how plotting two variables together can provide information
# that is missed when plotting each one separately.

# %%
# import the packages we are going to be using
import numpy as np # for getting our distribution
import pandas as pd # to handle data frames
import matplotlib.pyplot as plt # for plotting
import seaborn as sns # for plotting
from scipy import stats # to compute statistics

# %%
# correlation coefficient r - When we have a r of 1 then we will get a perfectly
# upward sloping line, and if we have a r of -1, we will get
# a perfectly downward slopping line. A r of 0 will
# get us a 'cloud' of points. Here we will consider r=0.90, but you can try other values too.

# Simulate data to plot
r = 0.90
mean = [15, 5]
cov = [[1, r], [r, 1]]
x, y = x, y = np.random.multivariate_normal(mean, cov, 400).T

# Adjust the figure size
plt.figure(figsize=(10,5))

# Plot the histograms of X and Y
plt.subplot(1,2,1)
plt.hist(x = x, bins = 15)
plt.title("X")
plt.subplot(1,2,2)
plt.hist(x = y, bins = 15)
plt.title("Y")
plt.show()

# %%
# Plot the data (bivariate joint distributions must necessarily be visualized in a 2D or 3D axis system)
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.scatter(x = x, y = y)
plt.title("Joint Distribution of X and Y")
# Plot the Marginal X Distribution
plt.subplot(2,2,3)
plt.hist(x = x, bins = 15)
plt.title("Marginal Distribution of X")
# Plot the Marginal Y Distribution
plt.subplot(2,2,2)
plt.hist(x = y, orientation = "horizontal", bins = 15)
plt.title("Marginal Distribution of Y")

plt.show()

# %% [markdown]
# #### 2D visualization of bivariate normal distribution

# %%
from mpl_toolkits import mplot3d
from matplotlib import cm
from scipy.stats import multivariate_normal

plt.subplots(figsize=(5, 5)) # define figure size

mu = np.array([2.1, 1.9]) # mean of x and y
sdx = 0.6 # standard deviation of x
sdy = 0.4 # standard deviation of y
r = 0.6 # correlation
cov = np.array([[sdx**2, sdx*sdy*r],[sdy*sdx*r, sdy**2]]) # covariance matrix
rv = np.random.multivariate_normal(mu, cov, 1000) # produce a multivariate random variable (array of 2 random variables)
da = pd.DataFrame(rv) # convert the array to dataframe (1000x2 table)
da.rename({0: 'X', 1: 'Y'}, axis=1, inplace=True)

sns.kdeplot(x=da['X'], y=da['Y'], fill=True, cmap=cm.coolwarm, bw_adjust=10, levels=100, thresh=0)
plt.show()

# %% [markdown]
# #### 3D visualization of bivariate normal distribution

# %%
from mpl_toolkits import mplot3d
from matplotlib import cm
from scipy.stats import multivariate_normal

# Simulate data
mu = np.array([2.1, 1.9]) # mean of x and y
sdx = 0.6 # standard deviation of x
sdy = 0.4 # standard deviation of y
r = 0.6 # correlation
cov = np.array([[sdx**2, sdx*sdy*r],[sdy*sdx*r, sdy**2]]) # covariance matrix
rv = multivariate_normal(mu, cov) # produce a multivariate random variable

x = np.linspace(0, 4, num=300) # linspace - Return evenly spaced numbers over a specified interval (num=Number of samples to generate)
y = np.linspace(0, 4, num=300)
X, Y = np.meshgrid(x, y) # Return coordinate matrices from coordinate vectors.
pos = np.dstack((X, Y)) # Stack array

Z = rv.pdf(pos) # Probability density function applied to the stacked array

# %%
# Produce 3D plot (uncheck some lines of code with "#"" to understand what they do)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d') # 111 means 1x1 grid, first subplot, projection is defined as 3D
ax.plot_surface(X, Y, Z, rstride=2, cstride=2, cmap=cm.coolwarm, antialiased=False ) # antialiased - removes grid from surface; The rstride and cstride kwargs set the stride used to sample the input data to generate the graph
ax.view_init(30, -125) # change the angles (vertical, horizontal)

cset = ax.contour(X, Y, Z, zdir='x', levels=1, offset=4.2, cmap='Blues') # contor line in x with 1 level
cset = ax.contour(X, Y, Z, zdir='y', levels=1, offset=4.2, cmap='Blues') # contor line in y with 1 level

#draw filled probability density function
#cset = ax.contourf(X, Y, Z, zdir='x', levels=1, alpha=0.3, offset=4.2, cmap='Blues')
#cset = ax.contourf(X, Y, Z, zdir='y', levels=1, alpha=0.3, offset=4.2, cmap='Blues')

plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0) # adjust the spacing of the subplots (left, bottom, right, top, wspace - width space, hspace - height space)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %% [markdown]
# ### 2. Run correlation analysis
#
# Correlation analysis is a very common procedure in exploratory data analysis to explore relationships between variables in a dataset. Although correlation does not imply causation, causation most often imply correlation. Hence, complemented with regression-based methods, they are important basis to establish hypothesis to be tested with further confirmatory statistics.

# %% [markdown]
# #### Example with the [penguin](https://www.kaggle.com/datasets/parulpandey/palmer-archipelago-antarctica-penguin-data) dataset
#
# The penguin dataset provides biometric data for 3 species of penguins from the Palmer Archipelago (Antarctica). The more relevant variables are:
#
# * Species: penguin species (Chinstrap, Adélie, or Gentoo)
# * Island: island name (Dream, Torgersen, or Biscoe) in the Palmer Archipelago (Antarctica)
# * Culmen Length (mm) - length of "the upper ridge of a bird's beak"
# * Culmen Depth (mm) - depth of "the upper ridge of a bird's beak"
# * Flipper Length (mm) - length of the flippers (penguin's wings)
# * Body mass (g)
# * Sex: penguin sex
#
# ![Alt text](https://pbs.twimg.com/media/EaAXQn8U4AAoKUj.jpg:small)

# %%
data = pd.read_csv('penguins_lter.csv', sep=";") # read the data (sep - separator, in this case we have a ";" instead of a ",")
data.drop(data.iloc[:,14:18], axis=1, inplace=True) # drop the columns 14 to 17 (axis=1 means we are dropping columns, inplace=True means we are modifying the original dataframe)
data = data.dropna() # drop the rows with missing values (dropna - drop missing values)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 333 entries, 0 to 343
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            333 non-null    object
#  1   Sample Number        333 non-null    int64
#  2   Species              333 non-null    object
#  3   Region               333 non-null    object
#  4   Island               333 non-null    object
#  5   Stage                333 non-null    object
#  6   Individual ID        333 non-null    object
#  7   Clutch Completion    333 non-null    object
#  8   Date Egg             333 non-null    object
#  9   Culmen Length (mm)   333 non-null    float64
#  10  Culmen Depth (mm)    333 non-null    float64
#  11  Flipper Length (mm)  333 non-null    float64
#  12  Body Mass (g)        333 non-null    float64
#  13  Sex                  333 non-null    object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 39.0+ KB

# %% [markdown]
# ##### Test correlation between flipper length and body mass of *penguins* individuals and compare results with rank correlation approaches

# %%
# test Pearson's correlation between flipper length and body mass
stat, p = stats.pearsonr(x=data["Flipper Length (mm)"], y=data["Body Mass (g)"]) # pearsonr - Calculate a Pearson correlation coefficient and the p-value for testing non-correlation.
print('r=%.3f, p-value=%.3f' % (stat, p)) # print the correlation coefficient and the p-value (r=correlation coefficient, p-value=probability of observing the data if the null hypothesis is true)
# Out:
# r=0.873, p-value=0.000

# %%
# test Spearman's Rank Correlation between flipper length and body mass
stat, p = stats.spearmanr(a=data["Flipper Length (mm)"], b=data["Body Mass (g)"])
print('r=%.3f, p-value=%.3f' % (stat, p))
# Out:
# r=0.840, p-value=0.000

# %%
# test Kendall’s Rank Correlation between flipper length and body mass
stat, p = stats.kendalltau(x=data["Flipper Length (mm)"], y=data["Body Mass (g)"])
print('r=%.3f, p-value=%.3f' % (stat, p))
# Out:
# r=0.661, p-value=0.000

# %% [markdown]
# #### Visualizing correlation
#
# The most obvious form of visualizing correlations is using a scatterplot. However, matplotlib, seaborn and other python modules provide easy ways of producing other more informative and appealing visualizations.

# %%
# Scatter plots
sns.scatterplot(x=data["Flipper Length (mm)"], y=data["Body Mass (g)"])
plt.show()

# %%
# Scatter plots with group defined by Species
plt.subplots(figsize=(8, 8)) # define figure size
sns.scatterplot(x=data["Flipper Length (mm)"], y=data["Body Mass (g)"], hue = data['Species']) # hue - group by color (hue - group by color, in this case we are grouping by species)
plt.legend(title='Species', fontsize='12', title_fontsize='14')
# plt.legend(bbox_to_anchor=(1.02, 1), title='Species', fontsize='12', title_fontsize='14') # to place the legend outside the plot area
plt.show()

# %%
# Scatter plots with group defined by Sex
plt.subplots(figsize=(8, 8))
sns.scatterplot(x=data["Flipper Length (mm)"], y=data["Body Mass (g)"], hue = data['Sex']) # hue - group by color (hue - group by color, in this case
plt.legend(title='Species', fontsize='12', title_fontsize='14')
# plt.legend(bbox_to_anchor=(1.02, 1), title='Species', fontsize='12', title_fontsize='14') # to place the legend outside the plot area
plt.show()

# %%
# Kernel density plots
sns.kdeplot(x=data["Flipper Length (mm)"], y=data["Body Mass (g)"], cmap="Blues", fill=True, thresh=0)
plt.show()

# %%
# Composed plots with scatterplot and histograms
stat, p = stats.pearsonr(x=data["Flipper Length (mm)"], y=data["Body Mass (g)"])

g=sns.jointplot(x=data["Flipper Length (mm)"], y=data["Body Mass (g)"], kind='reg', data=data, joint_kws={'line_kws':{'color':'red'}}) # kind - kind of plot to draw (reg - regression), joint_kws - keyword arguments for the joint plot (line_kws - keyword arguments for the regression line, in this case we are changing the color to red)
g.ax_joint.text(x=175, y=6000, s=('r=%.3f, p-value=%.3f' % (stat, p))) # to show results from the correlation test
plt.show()

# %%
# Composed Kernel density plots
stat, p = stats.pearsonr(x=data["Flipper Length (mm)"], y=data["Body Mass (g)"])

g=sns.jointplot(x=data["Flipper Length (mm)"], y=data["Body Mass (g)"], kind='kde', data=data, fill=True, cmap="Blues")
g.ax_joint.text(x=175, y=6000, s=('r=%.3f, p-value=%.3f' % (stat, p)))
plt.show()

# %%
# Scatterplot with histograms and Kernel Density

g=sns.jointplot(x=data["Flipper Length (mm)"], y=data["Body Mass (g)"], data=data)
g.plot_joint(sns.kdeplot, color="r", zorder=0, levels=6) # plot_joint - Plot a bivariate joint distribution with several different possible visualizations (sns.kdeplot - kernel density estimation, color - color of the plot, zorder - order of the plot, levels - number of contour levels to draw)
g.plot_marginals(sns.rugplot, color="r", height=-.15, clip_on=False)
plt.show()

# %% [markdown]
# ### 3. Correlation matrices
#
# Correlation matrices is an important output of multivariate exploratory data analysis. It is also the basis of multivariate Ordination techniques such as Principal Components Analysis. It provides an important overview of wich variables in our dataset are more related with each other. Multicolinearity is a major issue for regression-based as well as other modelling approaches, including machine learning. The graphical analysis of multicolinearity is an essential step to select predictor variables for modelling purposes.
#
# Different visualizations are more or less adequate depending on the purposes as well as the number of targeted variables of correlation analysis.

# %%
list(data.columns)
# Out:
# ['studyName',
#  'Sample Number',
#  'Species',
#  'Region',
#  'Island',
#  'Stage',
#  'Individual ID',
#  'Clutch Completion',
#  'Date Egg',
#  'Culmen Length (mm)',
#  'Culmen Depth (mm)',
#  'Flipper Length (mm)',
#  'Body Mass (g)',
#  'Sex']

# %%
# Scatterplots and histograms
import seaborn as sns
data_sel = data.iloc[:,[2,9,10,11,12,13]]
sns.pairplot(data_sel);

# %%
# Scatterplots and KDE - categorized by "species"
import seaborn as sns
sns.pairplot(data_sel, hue='Species')
plt.show()

# %%
data_sel.corr(numeric_only=True)
# Out:
#                      Culmen Length (mm)  Culmen Depth (mm)  \
# Culmen Length (mm)             1.000000          -0.228626
# Culmen Depth (mm)             -0.228626           1.000000
# Flipper Length (mm)            0.653096          -0.577792
# Body Mass (g)                  0.589451          -0.472016
#
#                      Flipper Length (mm)  Body Mass (g)
# Culmen Length (mm)              0.653096       0.589451
# Culmen Depth (mm)              -0.577792      -0.472016
# Flipper Length (mm)             1.000000       0.872979
# Body Mass (g)                   0.872979       1.000000

# %%
# correlation map or heatplot
f,ax = plt.subplots(figsize=(10, 7))
sns.heatmap(data_sel.corr(numeric_only=True), annot=True, linewidths=.5, fmt= '.1f', ax=ax, cmap='coolwarm_r') # '_r' after the palette name reverse the color order of the palette
plt.show()

# NOTE:

# %%
# Composite plot mixing scatterplots and univariate/bivariate Kernel Density Estimates

plt.rcParams["axes.labelsize"] = 18
g = sns.PairGrid(data_sel, diag_sharey=False)
axes = g.axes
g.map_upper(plt.scatter,  linewidths=1,
            edgecolor="w", s=90, alpha = 0.5)
g.map_diag(sns.kdeplot, lw = 4, legend=False)
g.map_lower(sns.kdeplot, cmap="Blues_d")
plt.show()

# %%
# Composite plot mixing scatterplots, smoothed lines, histograms and tabular charts (R-style)

import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import numpy as np

def corrdot(*args, **kwargs):
    corr_r = args[0].corr(args[1], 'pearson')
    corr_text = round(corr_r, 2)
    ax = plt.gca()
    font_size = abs(corr_r) * 60 + 5
    ax.annotate(corr_text, [.5, .5,],  xycoords="axes fraction",
                ha='center', va='center', fontsize=font_size)

def corrfunc(x, y, **kws):
    r, p = stats.pearsonr(x, y)
    p_stars = ''
    if p <= 0.05:
        p_stars = '*'
    if p <= 0.01:
        p_stars = '**'
    if p <= 0.001:
        p_stars = '***'
    ax = plt.gca()
    ax.annotate(p_stars, xy=(0.65, 0.6), xycoords=ax.transAxes,
                color='red', fontsize=50)

sns.set(style='white', font_scale=1.6)
g = sns.PairGrid(data_sel, aspect=1.5, diag_sharey=False, despine=False)
g.map_lower(sns.regplot, lowess=True, ci=False,
            line_kws={'color': 'red', 'lw': 1},
            scatter_kws={'color': 'black', 's': 20})
g.map_diag(sns.histplot,
           kde=True,
           color = 'red',
           edgecolor = 'k',
           facecolor = 'lightgrey')
g.map_diag(sns.rugplot, color='black')
g.map_upper(corrdot)
g.map_upper(corrfunc)
g.fig.subplots_adjust(wspace=0, hspace=0)

# Remove axis labels
for ax in g.axes.flatten():
    ax.set_ylabel('')
    ax.set_xlabel('')

# Add titles to the diagonal axes/subplots
for ax, col in zip(np.diag(g.axes), data_sel.columns):
    ax.set_title(col, y=0.85, fontsize=22)

# %%
# Same thing but more appealling and adding bubble charts

import matplotlib.pyplot as plt
import seaborn as sns

def corrdot(*args, **kwargs):
    corr_r = args[0].corr(args[1], 'pearson')
    corr_text = f"{corr_r:2.2f}".replace("0.", ".")
    ax = plt.gca()
    ax.set_axis_off()
    marker_size = abs(corr_r) * 10000
    ax.scatter([.5], [.5], marker_size, [corr_r], alpha=0.6, cmap="coolwarm",
               vmin=-1, vmax=1, transform=ax.transAxes)
    font_size = abs(corr_r) * 40 + 5
    ax.annotate(corr_text, [.5, .5,],  xycoords="axes fraction",
                ha='center', va='center', fontsize=font_size)

sns.set(style='white', font_scale=1.6)
g = sns.PairGrid(data_sel, aspect=1.4, diag_sharey=False)
g.map_lower(sns.regplot, lowess=True, ci=False, line_kws={'color': 'black'})
g.map_diag(sns.histplot, kde_kws={'color': 'black'})
g.map_upper(corrdot);

# %%
# A tabular chart with correlation values, the overall shape of the relationship, emphasized with a color gradient

# !pip install biokit
from biokit import Corrplot #
corr = data_sel.corr(method='spearman', numeric_only=True)
c = Corrplot(corr)
c.plot(method='ellipse', grid=True, shrink=1, rotation=45, upper='text', lower='ellipse')
fig = plt.gcf()
fig.set_size_inches(10, 8)


# NOTE: The installation of Biokit returns an error using Python 3.14.3
# Out:
# Requirement already satisfied: biokit in /usr/local/lib/python3.12/dist-packages (0.5.0)
# Requirement already satisfied: easydev>=0.9.34 in /usr/local/lib/python3.12/dist-packages (from biokit) (0.13.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from biokit) (2.2.2)
# Requirement already satisfied: bioservices>=1.4.5 in /usr/local/lib/python3.12/dist-packages (from biokit) (1.16.0)
# Requirement already satisfied: colormap in /usr/local/lib/python3.12/dist-packages (from biokit) (1.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from biokit) (1.16.3)
# Requirement already satisfied: biopython in /usr/local/lib/python3.12/dist-packages (from biokit) (1.87)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from biokit) (3.10.0)
# Requirement already satisfied: numpydoc in /usr/local/lib/python3.12/dist-packages (from biokit) (1.10.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from biokit) (6.10.1)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in /usr/local/lib/python3.12/dist-packages (from bioservices>=1.4.5->biokit) (1.4.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.12/dist-packages (from bioservices>=1.4.5->biokit) (4.13.5)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from bioservices>=1.4.5->biokit) (8.4.0)
# Requirement already satisfied: grequests<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from bioservices>=1.4.5->biokit) (0.7.0)
# Requirement already satisfied: lxml<6.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from bioservices>=1.4.5->biokit) (5.4.0)
# Requirement already satisfied: numpy<2.4,>=1.23.2 in /usr/local/lib/python3.12/dist-packages (from bioservices>=1.4.5->biokit) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.12/dist-packages (from bioservices>=1.4.5->biokit) (2.32.4)
# Requirement already satisfied: requests-cache<2.0.0,>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from bioservices>=1.4.5->biokit) (1.3.2)
# Requirement already satisfied: rich-click<2.0.0,>=1.8.5 in /usr/local/lib/python3.12/dist-packages (from bioservices>=1.4.5->biokit) (1.9.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.67.1 in /usr/local/lib/python3.12/dist-packages (from bioservices>=1.4.5->biokit) (4.67.3)
# Requirement already satisfied: wrapt<2.0.0,>=1.17.2 in /usr/local/lib/python3.12/dist-packages (from bioservices>=1.4.5->biokit) (1.17.3)
# Requirement already satisfied: xmltodict<0.15.0,>=0.14.2 in /usr/local/lib/python3.12/dist-packages (from bioservices>=1.4.5->biokit) (0.14.2)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in /usr/local/lib/python3.12/dist-packages (from easydev>=0.9.34->biokit) (0.4.6)
# Requirement already satisfied: line-profiler<5.0.0,>=4.1.2 in /usr/local/lib/python3.12/dist-packages (from easydev>=0.9.34->biokit) (4.2.0)
# Requirement already satisfied: pexpect<5.0.0,>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from easydev>=0.9.34->biokit) (4.9.0)
# Requirement already satisfied: platformdirs<5.0.0,>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from easydev>=0.9.34->biokit) (4.9.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->biokit) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->biokit) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->biokit) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->biokit) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->biokit) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->biokit) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->biokit) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->biokit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->biokit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->biokit) (2026.2)
# Requirement already satisfied: sphinx>=6 in /usr/local/lib/python3.12/dist-packages (from numpydoc->biokit) (8.2.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->bioservices>=1.4.5->biokit) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->bioservices>=1.4.5->biokit) (4.15.0)
# Requirement already satisfied: gevent in /usr/local/lib/python3.12/dist-packages (from grequests<0.8.0,>=0.7.0->bioservices>=1.4.5->biokit) (26.5.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect<5.0.0,>=4.9.0->easydev>=0.9.34->biokit) (0.7.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->biokit) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->bioservices>=1.4.5->biokit) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->bioservices>=1.4.5->biokit) (3.15)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->bioservices>=1.4.5->biokit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->bioservices>=1.4.5->biokit) (2026.5.20)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache<2.0.0,>=1.2.1->bioservices>=1.4.5->biokit) (26.1.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache<2.0.0,>=1.2.1->bioservices>=1.4.5->biokit) (26.1.0)
# Requirement already satisfied: url-normalize>=2.0 in /usr/local/lib/python3.12/dist-packages (from requests-cache<2.0.0,>=1.2.1->bioservices>=1.4.5->biokit) (3.0.0)
# Requirement already satisfied: rich>=12 in /usr/local/lib/python3.12/dist-packages (from rich-click<2.0.0,>=1.8.5->bioservices>=1.4.5->biokit) (13.9.4)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.12/dist-packages (from sphinx>=6->numpydoc->biokit) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=6->numpydoc->biokit) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=6->numpydoc->biokit) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from sphinx>=6->numpydoc->biokit) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=6->numpydoc->biokit) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.12/dist-packages (from sphinx>=6->numpydoc->biokit) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.12/dist-packages (from sphinx>=6->numpydoc->biokit) (3.1.6)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.12/dist-packages (from sphinx>=6->numpydoc->biokit) (2.20.0)
# Requirement already satisfied: docutils<0.22,>=0.20 in /usr/local/lib/python3.12/dist-packages (from sphinx>=6->numpydoc->biokit) (0.21.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.12/dist-packages (from sphinx>=6->numpydoc->biokit) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.12/dist-packages (from sphinx>=6->numpydoc->biokit) (2.18.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.12/dist-packages (from sphinx>=6->numpydoc->biokit) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.12/dist-packages (from sphinx>=6->numpydoc->biokit) (2.0.0)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from sphinx>=6->numpydoc->biokit) (4.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from Jinja2>=3.1->sphinx>=6->numpydoc->biokit) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12->rich-click<2.0.0,>=1.8.5->bioservices>=1.4.5->biokit) (4.2.0)
# Requirement already satisfied: roman-numerals==4.1.0 in /usr/local/lib/python3.12/dist-packages (from roman-numerals-py>=1.0.0->sphinx>=6->numpydoc->biokit) (4.1.0)
# Requirement already satisfied: greenlet>=3.2.2 in /usr/local/lib/python3.12/dist-packages (from gevent->grequests<0.8.0,>=0.7.0->bioservices>=1.4.5->biokit) (3.5.1)
# Requirement already satisfied: zope.event in /usr/local/lib/python3.12/dist-packages (from gevent->grequests<0.8.0,>=0.7.0->bioservices>=1.4.5->biokit) (6.2)
# Requirement already satisfied: zope.interface in /usr/local/lib/python3.12/dist-packages (from gevent->grequests<0.8.0,>=0.7.0->bioservices>=1.4.5->biokit) (8.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12->rich-click<2.0.0,>=1.8.5->bioservices>=1.4.5->biokit) (0.1.2)
